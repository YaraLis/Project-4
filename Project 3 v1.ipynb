# %%
import requests
from bs4 import BeautifulSoup

import pandas as pd

# %%
import requests

headers = {"user-agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/118.0.0.0 Safari/537.36"}

r = requests.get("https://www.standvirtual.com/carros", headers = headers)
r.status_code
# Out:
# 200

# %%
r.content
# Out:
# b'<!DOCTYPE html><html lang="pt" dir="ltr"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1"/><meta property="fb:app_id" content="1440170512890527"/><meta property="og:url" content="https://www.standvirtual.com/carros"/><meta property="og:type" content="website"/><meta property="og:image" content="//statics.standvirtual.com/optimus-storage/a/carspt/images/fb-image200x200.png"/><meta property="og:site_name" content="standvirtual.com"/><meta property="al:ios:app_store_id" content="635240368"/><meta property="al:ios:app_name" content="Standvirtual"/><meta property="al:ios:url" content="standvirtual://www.standvirtual.com/carros"/><meta property="al:android:app_name" content="Standvirtual"/><meta property="al:android:package" content="com.fixeads.standvirtual"/><meta property="al:android:url" content="https://www.standvirtual.com/carros"/><meta property="al:web:url" content="https://www.standvirtual.com"/><meta property="al:web:should_fallba
# ...

# %%
soup=BeautifulSoup(r.content)
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
soup

# %%
#key-feature key-feature--firstRegistration 
#key-feature key-feature--firstRegistration

# %% [markdown]
# # **PRICE**

# %%
price= soup.find_all("div", attrs = {"class":"ooa-1t7cj0c ermhljg4"})[0].get_text().strip()
pric
# Out:
# '19 950EUR'

# %% [markdown]
# # **YEAR OF REGISTRATION**

# %%
registration= soup.find_all("dd", attrs = {"data-parameter":"first_registration_year"})[0].get_text().strip()
registration
# Out:
# '2018'

# %% [markdown]
# # FUNCTION

# %%
car_dict = {}
car_index = 0

for car in products:
    brand = 
    model = 
    price =  soup.find_all("div", attrs = {"class":"ooa-1t7cj0c ermhljg4"})[0].get_text().strip()
    registration = soup.find_all("dd", attrs = {"data-parameter":"first_registration_year"})[0].get_text().strip()

    print(name, model)
    
    car_dict[car_index] = {"brand":brand,  #bike_index es por si aparecen dos numeros iguales, se itene el indice para que no se repitan
                            "model":model,
                           'price' : price,
                             "registration": registration}

    car_index += 1
car_dict
